# %%
import tensorflow as tf
import numpy as np
import gzip
import pickle 
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.utils.class_weight import compute_sample_weight
import yaml
from os.path import isfile 
from myutils.graph_utils import FILTERS
from myutils.moldesc import process_smiles, adjacency_to_distance, zero_pad
from copy import deepcopy
from rdkit import Chem
from rdkit.Chem import AllChem
from keras_dgl.layers import MultiGraphCNN, MultiGraphAttentionCNN, GraphConvLSTM
import keras
from keras.utils import plot_model

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import StandardScaler

# %%
def gzload(name, f32=True):
    with gzip.open(name, 'rb') as f:
        data = np.load(f)
        if f32:
            data = np.nan_to_num(data.astype(np.float32))
        return data

# %%
def __balance_data(data_pos, data_neg, data_balance):
    lenghts = len(data_pos), len(data_neg)
    min_shape = min(lenghts)
    max_shape = max(lenghts)
   
    if data_balance == 'cut':
        data_pos = data_pos[:min_shape,:]
        data_neg = data_neg[:min_shape,:]
    elif data_balance == 'random':
        idx = np.random.choice(np.arange(max_shape), min_shape, replace=False)
        if max_shape==lenghts[0]:
            data_pos = data_pos[idx,:]
        else:
            data_neg = data_neg[idx,:]

# %%
approved = gzload('/data/project/joebrother/Druglikeness/drugability/data/drugs_approved_rdkit.npz')
withdrawn = gzload('/data/project/joebrother/Druglikeness/drugability/data/drugs_withdrawn_rdkit.npz')
zinc = gzload('/data/project/joebrother/Druglikeness/drugability/data/zinc15_nondrugs_sample_rdkit.npz')
non_zero_idx = gzload('/data/project/joebrother/Druglikeness/drugability/data/zinc15_nondrugs_sample_rdkit_idx.npz')
IDX = numpy_load('/data/project/joebrother/Druglikeness/drugability/data/zinc15_nondrugs_sample_rdkit_idx.npz').astype(int)
curated_withdrawn = withdrawn[:,IDX]

# %%
def load_from_config(config_dict, force, use_idx=True):
    kind = config_dict['loader_config'].get('kind', None)
    if kind is None:
        kind = config_dict['model_params'].get('kind', 'rdkit_ae')
      
    if kind in ['multitask_clf', 'multitask_disengaged']:
        return load_multitask_clf(config_dict, force)
    elif kind in ['ggnn', 'gcnn']:
        return load_graph_data(config_dict, force)
    elif kind=='ggnn_compressed':
        return load_compressed_data(config_dict, force)
    elif kind in ['rbm', 'morgan']:
        return load_morgan(config_dict, force)
    elif not (kind in ['rdkit_ae', 'mold2_ae']):
        raise KeyError('Unknown data preprocessing function')
   
   #PROJECT-SPECIFIC!!
    positive_idx = config_dict.get('drugs_idx', None)
    negative_idx = config_dict.get('non_drugs_idx', None)
    data_list_file = config_dict.get('data_list', None)
    if None in [positive_idx, negative_idx, data_list_file]:
        use_idx = False
    else:
        data_list = load_yaml(data_list_file)
        positive_file = data_list['vectorized_drugs'][positive_idx]
        negative_file = data_list['vectorized_non_drugs'][negative_idx]

    loader_cfg = config_dict['loader_config']
   ##!! mutable !!
    if use_idx:
        loader_cfg['positive_file']=positive_file
        loader_cfg['negative_file']=negative_file
    else:
        positive_file = loader_cfg['positive_file']
        negative_file = loader_cfg['negative_file']
   ##
    #data_checkpoint = loader_cfg['data_checkpoint']
    data_checkpoint = 'experiments/211014/rdkit_ae_zinc'
    data_balance = loader_cfg['data_balance']
    idx = _make_indices_from_config(loader_cfg)

    return load_data(positive_file, [negative_file], data_checkpoint, data_balance, idx, True, force)

# %%
def _make_indices_from_config(loader_cfg):
    non_zero_idx = loader_cfg.get('non_zero_idx', None)
    data_mu = loader_cfg.get('data_mu', None)
    data_std = loader_cfg.get('data_std', None)
    idx = (data_mu, data_std, non_zero_idx)
    return idx

# %%
def __load_data(data_pos, data_neg, data_checkpoint, data_balance, idx, standarize=True):
    data_pos = np.nan_to_num(gzload(data_pos))
    data_neg = np.nan_to_num(np.vstack([gzload(x) for x in data_neg]))
    x, y, weights = __balance_data(data_pos, data_neg, data_balance)
   
    x = _normalize(x, idx, standarize)

    y = OneHotEncoder(sparse=False).fit_transform(y.reshape(-1,1))
    gz_pickle(data_checkpoint, (x, y, weights))
    return x, y, weights


def load_data(data_pos, data_neg, data_checkpoint, data_balance, idx, standarize=True, force=False):
    if None in [data_pos, data_neg] or not isfile(data_checkpoint):
        force=True
    if force:
        return __load_data(data_pos, data_neg, data_checkpoint, data_balance, idx, standarize)
    else:
        return gz_unpickle(data_checkpoint)

# %%
def __balance_data(data_pos, data_neg, data_balance):
    lenghts = len(data_pos), len(data_neg)
    min_shape = min(lenghts)
    max_shape = max(lenghts)
   
    if data_balance == 'cut':
        data_pos = data_pos[:min_shape,:]
        data_neg = data_neg[:min_shape,:]
    elif data_balance == 'random':
        idx = np.random.choice(np.arange(max_shape), min_shape, replace=False)
        if max_shape==lenghts[0]:
            data_pos = data_pos[idx,:]
        else:
            data_neg = data_neg[idx,:]

    print('pos,neg shapes:', data_pos.shape, data_neg.shape)
    x= np.vstack((data_pos, data_neg))
    y= np.array([1 for _ in range(data_pos.shape[0])] + [0 for _ in range(data_neg.shape[0])])

    if data_balance == 'weights':
        weights = compute_sample_weight('balanced', y)
    else:
        weights=None
   
    return x, y, weights

# %%
def load_graph_data(config_dict, force):
    loader_cfg = config_dict['loader_config']
    #data_checkpoint = loader_cfg['data_checkpoint']
    data_checkpoint = 'experiments/211014/gcnn_zinc.pkz'
    smiles_checkpoint = data_checkpoint.replace('.pkz','.smiles')
   
    if not isfile(data_checkpoint):
        force=True
    if not force:
        return gz_unpickle(data_checkpoint)
      
    processor = _smiles_data_processor

   #====== read ======
    all_smiles, Y, w = load_smiles_and_resample(loader_cfg, smiles_checkpoint)
   
   #====== processing =======
    tensor_dict = processor(all_smiles, config_dict['vectorization_config'])
   
   #====== joining and padding ============
    max_len_in_data = max(tensor_dict['L'])
    #max_len = loader_cfg.get('max_num_atoms', max(tensor_dict['L']))
    max_len = loader_cfg.get('max_num_atoms', 128)
    assert max_len_in_data<=max_len
    print('Max atom num: ',max_len)
    F = tensor_dict['F']
    lens = tensor_dict['L']

    X = [zero_pad(x, (max_len, F)) for x in tensor_dict['X']]
    A = [zero_pad(x, (max_len, max_len)) for x in tensor_dict['A']]
    D = [zero_pad(x, (max_len, max_len)) for x in tensor_dict['D']]
   
    result = {}
    result['X'] = np.array(X)
    result['A'] = np.array(A)
    result['D'] = np.array(D)
    result['Y'] = np.array(Y)
    result['Y'] = OneHotEncoder(sparse=False).fit_transform(result['Y'].reshape(-1,1))
    result['L'] = np.array(lens)
    raw_chk = data_checkpoint.replace('.pkz','_raw_arrs.pkz')
    gz_pickle(raw_chk, result)
   
    filter_type = config_dict['graph_filters'].get('filter_type', 'first_order')
    adjacency_normalization = config_dict['graph_filters'].get('adjacency_normalization', True)
    filter_generator = FILTERS[filter_type]
    filters = filter_generator(result['A'], result['D'], adjacency_normalization)
   
   #order: X_input, filters_input, nums_input, identity_input, adjacency_input 
    data = result['X'], filters, result['L'], filters[:, :max_len, :], result['A']
    Y = result['Y']
    gz_pickle(data_checkpoint, (data, Y, w))
  
    loader_cfg['max_num_atoms'] = max_len
    return data, Y, w

# %%
def _smiles_data_processor(datalines, process_smiles_config, use_semi_colon=False):
    total_X, total_A, total_lens, total_D = [], [] , [], []
    for line in datalines:
        if use_semi_colon:
            line = line.split(';')[0]
        try:
            X, A = process_smiles(line, **process_smiles_config)
        except:
            print('Error with ',line)
            raise
        D = adjacency_to_distance(A, max_dist_to_include=10)
        n,f = X.shape
        total_lens.append(n)
        total_X.append(X)
        total_A.append(A)
        total_D.append(D)
    return {'X':total_X, 'A':total_A, 'L':total_lens, 'F':f, 'D':total_D}

# %%
def load_smiles_and_resample(config, smiles_chk):
    raw_data = {'positive':[], 'negative':[]}
    with open(config['positive_data_file'], 'r') as p: 
        raw_data['positive'] = p.readlines()
   
    for neg_name in config['negative_data_files']:
        with open(neg_name, 'r') as n: 
            raw_data['negative'].extend(n.readlines())
   
    positive = np.arange(len(raw_data['positive'])).reshape(-1,1)
    negative = -1 - np.arange(len(raw_data['negative'])).reshape(-1,1)

    x, y, w = __balance_data(positive, negative, config['data_balance'])
    x = x.astype(int)

    smiles_list = []
    smiles_chk = open(smiles_chk, 'w')

    for idx in x[:,0]:
        if idx<0:
            idx = -1 - idx
            flag = 0
            key = 'negative'         
        else:
            flag = 1 
            key = 'positive'
         
        smiles = raw_data[key][idx].strip()
        smiles_list.append(smiles)
        smiles_chk.write('%s %i\n'%(smiles, flag))
      
    smiles_chk.close()

    return smiles_list, y, w

# %%
def _normalize(x, idx, standarize):
    if type(idx).__name__=='str':
        idx_f=idx
        mu_f, std_f = None, None
    else:   
        mu_f, std_f, idx_f = idx
    if idx_f is None:
        return x
    if mu_f is None: mu_f = 'mean_' + idx_f
    if std_f is None: std_f = 'std_' + idx_f

    IDX = numpy_load(idx_f).astype(int)
    if standarize:
        std = numpy_load(std_f)
        mu = numpy_load(mu_f)
        x=np.nan_to_num((x-mu)/std)
    x=x[:,IDX]
   
    return x

# %%
def load_yaml(name):
    with open(name, 'r') as f:
        return yaml.load(f)
    
def gz_unpickle(name):
    with gzip.open(name, 'rb') as f:
        return pickle.load(f)
    
def numpy_load(name):
    ext = name[-3:]
    if ext=='npy':
        return np.load(name)
    elif ext=='npz':
        return gzload(name)
    else:
        raise IOError('Unknown extension %s'%ext)

def gz_pickle(name, obj):
    with gzip.open(name, 'wb') as f:
        pickle.dump(obj, f)

# %% [markdown]
# ## GCNN

# %%
g_config = load_yaml('/data/project/joebrother/Druglikeness/drugability/config_files/gcnn_zinc.yaml')
my_g_config = load_yaml('/data/project/joebrother/Druglikeness/drugability/config_files/my_gcnn_zinc.yaml')
# Out:
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/ipykernel_launcher.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
x, y, weights = load_from_config(g_config, False)
#order: X_input, filters_input, nums_input, identity_input, adjacency_input
# Out:
# pos,neg shapes: (1777, 1) (1777, 1)
# Max atom num:  128
# /data/project/joebrother/Druglikeness/drugability/myutils/graph_utils.py:25: RuntimeWarning: divide by zero encountered in power
#   deg = np.where(deg>0,deg**(-0.5),1)

# %%
m_x, m_y, m_weights = load_from_config(my_g_config, False)
t = [m_x[0][:238,:,:], m_x[1][:238,:,:], m_x[2][:238,], m_x[3][:238,:,:], m_x[4][:238,:,:]]
#order: X_input, filters_input, nums_input, identity_input, adjacency_input
# Out:
# pos,neg shapes: (238, 1) (238, 1)
# Max atom num:  128
# /data/project/joebrother/Druglikeness/drugability/myutils/graph_utils.py:25: RuntimeWarning: divide by zero encountered in power
#   deg = np.where(deg>0,deg**(-0.5),1)

# %%
gcnn_model = tf.keras.models.load_model('/data/project/joebrother/Druglikeness/drugability/experiments/211014/gcnn_zinc_train_model', custom_objects={'MultiGraphCNN':MultiGraphCNN})
feat_extraction_model = tf.keras.models.Model(inputs=gcnn_model.input, outputs=gcnn_model.get_layer(name="lambda_2").output)

# %%
gcnn_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 128, 9)]     0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 128, 128)]   0
# __________________________________________________________________________________________________
# gcnn1 (MultiGraphCNN)           (None, 128, 128)     1280        input_6[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128)     512         gcnn1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128, 128)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 256, 128)]   0
# __________________________________________________________________________________________________
# multi_graph_cnn_5 (MultiGraphCN (None, 128, 128)     32896       dropout_7[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128)     0           multi_graph_cnn_5[0][0]
# __________________________________________________________________________________________________
# multi_graph_cnn_6 (MultiGraphCN (None, 128, 128)     32896       dropout_8[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128)     0           multi_graph_cnn_6[0][0]
# __________________________________________________________________________________________________
# multi_graph_cnn_7 (MultiGraphCN (None, 128, 128)     32896       dropout_9[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128, 128)     0           multi_graph_cnn_7[0][0]
# __________________________________________________________________________________________________
# multi_graph_cnn_8 (MultiGraphCN (None, 128, 128)     32896       dropout_10[0][0]
#                                                                  input_7[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 128, 128)     0           multi_graph_cnn_8[0][0]
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, None)]       0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 128)          0           dropout_11[0][0]
#                                                                  input_10[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128)          0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            258         dropout_12[0][0]
# ==================================================================================================
# Total params: 133,634
# Trainable params: 133,378
# Non-trainable params: 256
# __________________________________________________________________________________________________

# %%
res = feat_extraction_model.predict(x)
m_res = feat_extraction_model.predict(t)

# %%
ap_rdkit = gzload('/data/project/joebrother/Druglikeness/drugability/data/drugs_approved_rdkit.npz')
ap_m2v = gzload('/data/project/joebrother/Druglikeness/drugability/data/drugs_approved_m2v.npz')
zin_rdkit = gzload('/data/project/joebrother/Druglikeness/drugability/data/zinc15_nondrugs_sample_rdkit.npz')
zin_m2v = gzload('/data/project/joebrother/Druglikeness/drugability/data/zinc15_nondrugs_sample_m2v.npz')

# %%
scaler = StandardScaler()
scaler.fit(res)
res = scaler.transform(res)
m_res = scaler.transform(m_res)

# %%
pca = PCA(n_components=2)
pca.fit(res)
row_data = pd.DataFrame(pca.transform(res))
my_data = pd.DataFrame(pca.transform(m_res))

y_l = pd.DataFrame(y)
y_l.columns = ['negative', 'label']
y_m = pd.DataFrame(m_y)
y_m.columns = ['negative', 'label']

row_data = pd.concat([row_data, y_l[['label']]], axis = 1)
my_data = pd.concat([my_data, y_m[['label']]], axis = 1)

for i in range(len(row_data)):
    if row_data['label'][i] == 1:
        row_data['label'][i] = 'Druglike'
    else:
        row_data['label'][i] = 'non-Drug'
# Out:
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=row_data, x = 0, y = 1, hue = 'label', palette = ['blue', 'orange'])
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# Text(0, 0.5, 'PC2')

# %%
r = pd.DataFrame(res)
r['label'] = y[:,1:]
for i in range(len(r)):
    if r['label'][i] == 1:
        r['label'][i] = 'Druglike'
    else:
        r['label'][i] = 'non-Drug'
m = pd.DataFrame(m_res)
m['label'] = 'withdrawn'
t_d = pd.concat([r,m], axis = 0).reset_index(drop=True)
# Out:
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /data/project/joebrother/anaconda3/envs/druglike/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
tsne = TSNE(n_components=2)
temp = pd.DataFrame(tsne.fit_transform(t_d.iloc[:,:-1]))
temp = pd.concat([temp, t_d[['label']]], axis = 1)

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=temp, x = 0, y = 1, hue = 'label', palette = ['blue', 'orange','red'])
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>
